# %% [markdown]
# # **NOTAS**

# %% [markdown]
# - Los parametros de entrada no deben cambiar su valor
#
# - Existen variables **globales** y **locales**
#
# - Lack of reusability = Falta de reudabilidad
#
# - **PROCEDURES**: procedimientos, rutinas, funciones, metodos
#
# - **CONTROL**: ifelse, for, while
#
# - `a = 'hola'` = `<clave> = <valor>`
#
# - *built in* es `__main__`
#
# - Acoplamiento; llevarte todas las funciones cuando solo quieres 1
#
# - First in Last out / Last in First out
#
# - En la **programación imperativa** el algoritmo no cambia
#
# - En la **programación funcional** indicas a la maquina lo que hacer, los datos varian
#
# - un error es una sentencia mal escrita
#
# - las assert que comprueban la entrada de una funcion se llaman precondición

# %% [markdown]
# ---

# %% [markdown]
# `python3 -m venv venv`
#
# `source venv/bin/activate`
#
# `pip list`
#
# `pip3 install -r requirements.txt`
#
# `(venv) pip3 install -U pytest`
#
# `(venv) pip freeze > requirements.txt`

# %% [markdown]
# crear entorno virtual
# installar pytest y coverage

# %% [markdown]
# ---

# %% [markdown]
# # **SIGLAS**

# %% [markdown]
# - ### **SOLID**
# **S** --> SRP = Principio de responsabilidad individual
# **O** --> Abierto a la extensión cerrado a la modificación
# **L** -->
# **I** -->
# **D** -->
#
# - ### **LEGB**
# **L** --> Local (`def`)
# **E** --> Englobe
# **G** --> Global (`hola.py`)
# **B** --> Built in (`__main__`)
#
# - ### **CRUD**
# **C** --> Crear
# **R** --> Leer
# **U** --> Update
# **D** --> Borrar

# %% [markdown]
# ---

# %% [markdown]
# # **IMPORTANTE EXAMEN**

# %% [markdown]
# **If you have referentially transparent code, if you have pure functions — all
# the data comes in its input arguments and everything goes out and
# leave no state behind — it’s incredibly reusable.**

# %% [markdown]
# ---

# %% [markdown]
# # **PRUEBA MASTERMIND**

# %%
# Analisis y diseño
def generar_codigo():
    return codigo

def colocar_ficha():
    # Syntactic sugar
    return intento == solucion

def colocar_pines():
    calcular_aciertos()
    mostrar_pines()

def play():
    solucion = generar_codigo()
    while not is_solved:
        for i in LEN_SOLUTION:
            intento = colocar_ficha()
    is_solved = comprobar_solucion(intento, solucion)
    colocar_pines()

# %% [markdown]
# ---
